# %%
import numpy as np
import pandas as pd
import pdbreader

# %%
df = pdbreader.read_pdb('trj.pdb')
df
# Out:
# {'HETATM':          model_id    id name loc_indicator resname chain  resid res_icode  \
#  0               0     1    B          None     BEA     A      1      None
#  1               0     2    B          None     BEA     A      2      None
#  2               0     3    B          None     BEA     A      3      None
#  3               0     4    B          None     BEA     A      4      None
#  4               0     5    B          None     BEA     A      5      None
#  ...           ...   ...  ...           ...     ...   ...    ...       ...
#  1999995       999  1996    B          None     BEA     A   1996      None
#  1999996       999  1997    B          None     BEA     A   1997      None
#  1999997       999  1998    B          None     BEA     A   1998      None
#  1999998       999  1999    B          None     BEA     A   1999      None
#  1999999       999  2000    B          None     BEA     A   2000      None
#
# ...

# %%
type(df)
# Out:
# dict

# %%
df.keys()
# Out:
# dict_keys(['HETATM', 'CONECT'])

# %%
atom = df.get('HETATM')
atom
# Out:
#          model_id    id name loc_indicator resname chain  resid res_icode  \
# 0               0     1    B          None     BEA     A      1      None
# 1               0     2    B          None     BEA     A      2      None
# 2               0     3    B          None     BEA     A      3      None
# 3               0     4    B          None     BEA     A      4      None
# 4               0     5    B          None     BEA     A      5      None
# ...           ...   ...  ...           ...     ...   ...    ...       ...
# 1999995       999  1996    B          None     BEA     A   1996      None
# 1999996       999  1997    B          None     BEA     A   1997      None
# 1999997       999  1998    B          None     BEA     A   1998      None
# 1999998       999  1999    B          None     BEA     A   1999      None
# 1999999       999  2000    B          None     BEA     A   2000      None
#
#              x      y       z  occupancy b_factor segment element charge
# ...

# %%
conect = df.get('CONECT')
conect
# Out:
#       parent         bonds
# 0          1           [2]
# 1          2        [1, 3]
# 2          3        [2, 4]
# 3          4        [3, 5]
# 4          5        [4, 6]
# ...      ...           ...
# 1995    1996  [1995, 1997]
# 1996    1997  [1996, 1998]
# 1997    1998  [1997, 1999]
# 1998    1999  [1998, 2000]
# 1999    2000        [1999]
#
# [2000 rows x 2 columns]
